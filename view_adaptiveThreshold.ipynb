# %%
import os
import pandas as pd
a=pd.read_csv("/Users/kailong/Desktop/rtEnv/rtSynth_rt/subjects/sub002/adaptiveThreshold.csv")
a
# Out:
#        sub  session  run  threshold  successful_trials  perfect_trials  \
# 0   sub002        2    1       0.60               12.0             6.0
# 1   sub002        2    2       0.60               12.0             8.0
# 2   sub002        2    3       0.60               12.0             3.0
# 3   sub002        2    4       0.60               10.0             3.0
# 4   sub002        2    5       0.60               11.0             8.0
# 5   sub002        2    6       0.60               12.0             6.0
# 6   sub002        2    7       0.65                8.0             3.0
# 7   sub002        2    8       0.65                6.0             1.0
# 8   sub002        2    9       0.65               11.0             3.0
# 9   sub002        2   10       0.70               10.0             5.0
# 10  sub002        3    1       0.70               10.0             3.0
# 11  sub002        3    2       0.65               10.0             5.0
# ...

# %%
history=pd.read_csv("/Users/kailong/Desktop/rtEnv/rtSynth_rt/subjects/sub002/ses4/feedback/sub002_10_history.csv")
history[['TR','TR_milgram']]
# Out:
#      TR  TR_milgram
# 0     9         8.0
# 1    10         9.0
# 2    11        10.0
# 3    12        11.0
# 4    13        12.0
# 5    23        22.0
# 6    24        23.0
# 7    25        24.0
# 8    26        25.0
# 9    27        26.0
# 10   37        36.0
# 11   38        37.0
# 12   39        38.0
# 13   40        39.0
# 14   41        40.0
# 15   51        50.0
# 16   52        51.0
# 17   53        52.0
# 18   54        53.0
# 19   55        54.0
# 20   65        64.0
# 21   66        65.0
# 22   67        66.0
# 23   68        67.0
# 24   69        68.0
# 25   79        78.0
# 26   80        79.0
# 27   81        80.0
# 28   82        81.0
# 29   83        82.0
# 30   93        92.0
# 31   94        93.0
# 32   95        94.0
# 33   96        95.0
# 34   97        96.0
# 35  107       106.0
# 36  108       107.0
# 37  109       108.0
# 38  110       109.0
# 39  111       110.0
# 40  121       120.0
# 41  122       121.0
# 42  123       122.0
# 43  124       123.0
# ...

# %%
history=pd.read_csv("/Users/kailong/Desktop/rtEnv/rtSynth_rt/subjects/sub002/ses4/feedback/sub002_9_history.csv")
history[['TR','TR_milgram']]
# [(a+1)==b for a,b in enumerate(list(history['TR_milgram']))]
print(f"{history[['TR','TR_milgram']].to_string(index=False)}")
# Out:
#   TR  TR_milgram
#    9         1.0
#   10         2.0
#   11         3.0
#   12         4.0
#   13         5.0
#   23         6.0
#   24         7.0
#   25         8.0
#   26         9.0
#   27        10.0
#   37        11.0
#   38        12.0
#   39        13.0
#   40        14.0
#   41        15.0
#   51        16.0
#   52        17.0
#   53        18.0
#   54        19.0
#   55        20.0
#   65        21.0
#   66        22.0
#   67        23.0
#   68        24.0
#   69        25.0
#   79        26.0
#   80        27.0
#   81        28.0
#   82        29.0
#   83        30.0
#   93        31.0
#   94        32.0
#   95        33.0
#   96        34.0
#   97        35.0
#  107        36.0
#  108        37.0
#  109        38.0
#  110        39.0
#  111        40.0
#  121        41.0
#  122        42.0
#  123        43.0
#  124        44.0
#  125        45.0
#  135        46.0
#  136        47.0
#  137        48.0
#  138        49.0
#  139        50.0
#  149        51.0
# ...

# %%
p=0.4
5*p*(1-p)**4+10*p**2*(1-p)**3+10*p**3*(1-p)**2+5*p**4*(1-p)+p**5
# Out:
# 0.9222400000000001

# %%
1-0.6**5
# Out:
# 0.9222400000000001

# %%
10*p**2*(1-p)**3+10*p**3*(1-p)**2+5*p**4*(1-p)+p**5
# Out:
# 0.6630400000000001

# %%
10*p**3*(1-p)**2+5*p**4*(1-p)+p**5
# Out:
# 0.3174400000000001

# %%
if 1:
    print(1)
    pass
else:
    print(2)
# Out:
# 1

# %%
import time
processing_start_time=time.time()
time.sleep(1)
processing_end_time=time.time()
print(f"{processing_end_time-processing_start_time} s passes when processing")
# Out:
# 2.0042781829833984 s passes when processing

# %%
import pandas as pd
a=pd.read_csv("/Users/kailong/Desktop/rtEnv/rtSynth_rt/subjects/sub002/ses4/feedback/sub002_10_history.csv")
a
# Out:
#      TR  morphParam    states  points    B_prob  TR_milgram     timestamp
# 0     9          13  feedback       0  0.755860         7.0  1.621205e+09
# 1    10           9  feedback       0  0.937379         8.0  1.621205e+09
# 2    11           9  feedback       0  0.808578         9.0  1.621205e+09
# 3    12           5  feedback       0  0.992583        10.0  1.621205e+09
# 4    13           5  feedback       0  0.671976        11.0  1.621205e+09
# 5    23          13  feedback       0  0.007506        21.0  1.621205e+09
# 6    24          13  feedback       0  0.044801        22.0  1.621205e+09
# 7    25          13  feedback       0  0.039180        23.0  1.621205e+09
# 8    26          13  feedback       0  0.039180        23.0  1.621205e+09
# 9    27          13  feedback       0  0.030399        25.0  1.621205e+09
# 10   37          13  feedback       0  0.431488        35.0  1.621206e+09
# 11   38          13  feedback       0  0.090262        36.0  1.621206e+09
# ...

# %%
history=pd.read_csv("/Users/kailong/Desktop/rtEnv/rtSynth_rt/subjects/sub002/ses4/feedback/sub002_10_history.csv")
history
# history['successful_trials']
# [['TR','TR_milgram']]
# # [(a+1)==b for a,b in enumerate(list(history['TR_milgram']))]
# print(f"{history[['TR','TR_milgram']].to_string(index=False)}")
# Out:
#      TR_scanner  morphParam states    B_prob  TR_milgram   Run     Sub  \
# 0             1         NaN    ITI       NaN         NaN  10.0  sub002
# 1             2         NaN    ITI       NaN         NaN  10.0  sub002
# 2             3         NaN    ITI       NaN         NaN  10.0  sub002
# 3             4         NaN    ITI  0.510009         1.0  10.0  sub002
# 4             5         NaN    ITI  0.587067         2.0  10.0  sub002
# ..          ...         ...    ...       ...         ...   ...     ...
# 168         169         1.0    ITI  0.755342       166.0  10.0  sub002
# 169         170         1.0    ITI  0.876991       167.0  10.0  sub002
# 170         171         1.0    ITI  0.633834       168.0  10.0  sub002
# 171         172         1.0    ITI  0.819717       169.0  10.0  sub002
# 172         173         1.0    ITI  0.472192       170.0  10.0  sub002
#
#      eachTime                                              image  \
# ...
